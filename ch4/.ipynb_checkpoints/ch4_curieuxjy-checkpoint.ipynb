# %%
import gym

# %%
from gym import envs
env_names = [spec.id for spec in envs.registry.all()]
for name in sorted(env_names):
    print(name)
# Out:
# Acrobot-v1
# Adventure-ram-v0
# Adventure-ram-v4
# Adventure-ramDeterministic-v0
# Adventure-ramDeterministic-v4
# Adventure-ramNoFrameskip-v0
# Adventure-ramNoFrameskip-v4
# Adventure-v0
# Adventure-v4
# AdventureDeterministic-v0
# AdventureDeterministic-v4
# AdventureNoFrameskip-v0
# AdventureNoFrameskip-v4
# AirRaid-ram-v0
# AirRaid-ram-v4
# AirRaid-ramDeterministic-v0
# AirRaid-ramDeterministic-v4
# AirRaid-ramNoFrameskip-v0
# AirRaid-ramNoFrameskip-v4
# AirRaid-v0
# AirRaid-v4
# AirRaidDeterministic-v0
# AirRaidDeterministic-v4
# AirRaidNoFrameskip-v0
# AirRaidNoFrameskip-v4
# Alien-ram-v0
# Alien-ram-v4
# Alien-ramDeterministic-v0
# Alien-ramDeterministic-v4
# Alien-ramNoFrameskip-v0
# Alien-ramNoFrameskip-v4
# Alien-v0
# Alien-v4
# AlienDeterministic-v0
# AlienDeterministic-v4
# AlienNoFrameskip-v0
# AlienNoFrameskip-v4
# Amidar-ram-v0
# Amidar-ram-v4
# Amidar-ramDeterministic-v0
# Amidar-ramDeterministic-v4
# Amidar-ramNoFrameskip-v0
# Amidar-ramNoFrameskip-v4
# Amidar-v0
# ...

# %%
import gym
# import sys

def run_gym_env(argv1, argv2):
    env = gym.make(argv1) # Name of the environment supplied as 1st argument
    env.reset()
    for _ in range(int(argv2)): # Number of steps to be run supplied as 2nd argument
        env.render()
        env.step(env.action_space.sample())
    env.close()
    
run_gym_env("Alien-ram-v0", 2000)

# %% [markdown]
# ```
# import gym
# env = gym.make("ENVIRONMENT_NAME")
# obs = env.reset() # The first arrow in the picture
# # Inner loop (roll out)
# action = agent.choose_action(obs) # The second arrow in the picture
# next_state, reward, done, info = env.step(action) # The third arrow (and
# more)
# obs = next_state
# # Repeat Inner loop (roll out)
# ```

# %%
import gym
env = gym.make("Qbert-v0")
MAX_NUM_EPISODES = 10
MAX_STEPS_PER_EPISODE = 500
# OUTER Loop
for episode in range(MAX_NUM_EPISODES):
    obs = env.reset()
    # INNER Loop
    for step in range(MAX_STEPS_PER_EPISODE):
        env.render()
        action = env.action_space.sample()
        # Sample random action. This will be replaced by our agent's action when we start developing the agent algorithms
        next_state, reward, done, info = env.step(action) 
        # Send the action to the environment and receive the next_state, reward and whether done or not
        obs = next_state

        if done is True:
            print("\n Episode #{} ended in {} steps.".format(episode, step+1))
            break
# Out:
#  Episode #0 ended in 475 steps.
#
#  Episode #1 ended in 419 steps.
#
#  Episode #2 ended in 449 steps.
#
#  Episode #3 ended in 396 steps.
#
#  Episode #4 ended in 357 steps.
#
#  Episode #5 ended in 421 steps.
#
#  Episode #6 ended in 359 steps.
#
#  Episode #7 ended in 345 steps.
#
#  Episode #8 ended in 432 steps.

# %%
import sys
import gym
from gym.spaces import *

def print_spaces(space):
    print(space)
    if isinstance(space, Box): # Print lower and upper bound if it's a Box space
        print("\n space.low: ", space.low)
        print("\n space.high: ", space.high)

    
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    print("Observation Space:")
    print_spaces(env.observation_space)
    print("Action Space:")
    print_spaces(env.action_space)
    try:
        print("Action description/meaning:",env.unwrapped.get_action_meanings())
    except AttributeError:
        pass
# Out:
# Observation Space:
# Box(4,)
#
#  space.low:  [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
#
#  space.high:  [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# Action Space:
# Discrete(2)

# %%
#Mujoco 라이센스!!!!!!
if __name__ == "__main__":
    env = gym.make("BipedalWalker-v3")
    print("Observation Space:")
    print_spaces(env.observation_space)
    print("Action Space:")
    print_spaces(env.action_space)
    try:
        print("Action description/meaning:",env.unwrapped.get_action_meanings())
    except AttributeError:
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-2fc8227494f1> in <module>
#       1 if __name__ == "__main__":
# ----> 2     env = gym.make("BipedalWalker-v3")
#       3     print("Observation Space:")
#       4     print_spaces(env.observation_space)
#       5     print("Action Space:")
#
# D:\Installation\Anaconda3\lib\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     140
#     141 def make(id, **kwargs):
# --> 142     return registry.make(id, **kwargs)
#     143
#     144 def spec(id):
#
# D:\Installation\Anaconda3\lib\site-packages\gym\envs\registration.py in make(self, path, **kwargs)
#      85             logger.info('Making new env: %s', path)
#      86         spec = self.spec(path)
# ---> 87         env = spec.make(**kwargs)
#      88         # We used to have people override _reset/_step rather than
# ...
